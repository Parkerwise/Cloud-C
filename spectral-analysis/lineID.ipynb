# %% [markdown]
# # A29

# %%
import sys
import os
# import XCLASS packages
from xclass import task_LineIdentification
path = "/home/parkerwise/Research/Cloud-C/spectral-analysis/A.spw29/"
LocalPath="/home/parkerwise/Research/xclass/xclass_pip_off/examples/LineID/"
os.chdir(path)


###########################################################################
# TO MODIFY BY THE USER


# define path and name of default molfit file
DefaultMolfitFile = "molecules.molfit"


# define path and name of obs. xml file
ObsXMLFileName = "A.spw29.0.xml"



# define upper limit of overestimation
MaxOverestimationHeight = 500.0


# define tolerance
Tolerance = 65.0


# define path and name of algorithm xml files
AlgorithmXMLFileSMF = LocalPath + "files/my_algorithm-settings.xml"
AlgorithmXMLFileOverAll = LocalPath + "files/my_algorithm-settings.xml"


# define lower limit for column density of core components
MinColumnDensityEmis = 0.0


# define lower limit for column density of foreground components
MinColumnDensityAbs = 0.0


# define source name
SourceName = ""

SelectedMolecules = []

# define list of so-called strong molecules
StrongMoleculeList = []


## define path and name of cluster file
clusterdef = ""
###########################################################################


# call LineID function
IdentifiedLines, JobDir = task_LineIdentification.LineIdentificationCore(
                        MaxOverestimationHeight = MaxOverestimationHeight,
                        SourceName = SourceName,
                        DefaultMolfitFile = DefaultMolfitFile,
                        Tolerance = Tolerance,
                        SelectedMolecules = SelectedMolecules,
                        StrongMoleculeList = StrongMoleculeList,
                        MinColumnDensityEmis = MinColumnDensityEmis,
                        MinColumnDensityAbs = MinColumnDensityAbs,
                        AlgorithmXMLFileSMF = AlgorithmXMLFileSMF,
                        AlgorithmXMLFileOverAll = AlgorithmXMLFileOverAll,
                        experimentalData = ObsXMLFileName,
                        clusterdef = clusterdef)
# Out:
# Start function LineIdentification:
#
#
# Creating job directory for function LineIdentification:
# 	/home/parkerwise/.xclass/run/LineIdentification/job__03-06-2024__18-36-44__951432509/
#
# All files of the current LineIdentification run are stored here!
#
#
#
#
# Reading data from sqlite3 database .. done!
# Analyze molecular data ..
# Number of molecules in the freq. range:  365
# excluded molecule =  c-H2C3O-18;v=0;ortho
# excluded molecule =  CH3CHO;v=0;E#1
# excluded molecule =  H2SO4;v=0;para
# excluded molecule =  c-C6H5CCH;v=0;ortho
# excluded molecule =  H2C(CCH)2;v=0;ortho
# excluded molecule =  CH3C-13-HO;v=0;
# excluded molecule =  c-C4H2(CH2)2;v=0;ortho
# excluded molecule =  H2C4S;v=0;ortho
# excluded molecule =  c-C6H5CCH;v=0;para
# excluded molecule =  CH3CHO;v=0;A#1
# excluded molecule =  CD3OH;v=0;
# excluded molecule =  c-C6H5CN;v=0;para
# excluded molecule =  c-C6H5CN;v=0;ortho
# excluded molecule =  c-C4H2(CH2)2;v=0;para
# excluded molecule =  CHD2OH;v=0;
# excluded molecule =  CH2F2;v4=1;ortho
# excluded molecule =  C-13-H3CHO;v15=1;
# excluded molecule =  CH3C8H;v=0;ortho
# excluded molecule =  CH3C8H;v=0;para
# excluded molecule =  CH3CHO;v15=2;A#1
# excluded molecule =  CH3C-13-HO;v15=1;
# excluded molecule =  c-D2C3O;v=0;ortho
# excluded molecule =  C-13-H3CHO;v=0;
# excluded molecule =  CH3CHO;v15=2;E#1
# excluded molecule =  CD3OH;v12=1;
# excluded molecule =  H2NCH2CN;v17=1;
# excluded molecule =  NH2CN;v=0;para
# excluded molecule =  CH3CHO;v15=1;A#1
# excluded molecule =  CH2F2;v=0;para
# excluded molecule =  CH2F2;v=0;ortho
# excluded molecule =  C2H5CN;v12=1;
# excluded molecule =  CH3CHO;v15=1-0;A#1
# excluded molecule =  H2O2;v4=1;ortho
#
#
# Creating directory for single molecule fits ..
#
# Prepare single molecule fit (1/365) for molecule:  (CH3)2C-13-HCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (2/365) for molecule:  (Z)-HC2CHCHCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (3/365) for molecule:  AA-n-C4H9CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (4/365) for molecule:  AG-n-C4H9CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (5/365) for molecule:  AlCl-37;v=4; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (6/365) for molecule:  AlF;v=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (7/365) for molecule:  C-13-H2(OH)CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (8/365) for molecule:  C-13-H3(CH3)CHCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (9/365) for molecule:  C-13-H3C-13-H2C-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (10/365) for molecule:  C-13-H3CH2C-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (11/365) for molecule:  C-13-H3CH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (12/365) for molecule:  C-13-H3OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (13/365) for molecule:  C-13-H3OH;v=0;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (14/365) for molecule:  C-13-H3SH;v12=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (15/365) for molecule:  C-13-H3SH;v12=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (16/365) for molecule:  C2H2O2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (17/365) for molecule:  C2H2O2;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (18/365) for molecule:  C2H2O2;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (19/365) for molecule:  C2H3C3N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (20/365) for molecule:  C2H3CHO;v18=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (21/365) for molecule:  C2H3CHO;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (22/365) for molecule:  C2H3CN;v11=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (23/365) for molecule:  C2H3CN;v15=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (24/365) for molecule:  C2H3CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (25/365) for molecule:  C2H3CN;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (26/365) for molecule:  C2H3CN;v=0;#2 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (27/365) for molecule:  C2H3NH2;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (28/365) for molecule:  C2H3OCHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (29/365) for molecule:  C2H5C-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (30/365) for molecule:  C2H5CCH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (31/365) for molecule:  C2H5CHCNCH3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (32/365) for molecule:  C2H5CN-15;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (33/365) for molecule:  C2H5CN;v20=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (34/365) for molecule:  C2H5CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (35/365) for molecule:  C2H5NC;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (36/365) for molecule:  C2H5NH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (37/365) for molecule:  C2H5OCHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (38/365) for molecule:  C2H5OH;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (39/365) for molecule:  C3C-13-CH;v=0;hyp2 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (40/365) for molecule:  C3CHCH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (41/365) for molecule:  C3H6O2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (42/365) for molecule:  C3H7CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (43/365) for molecule:  C3H8;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (44/365) for molecule:  C3O3H6;v28=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (45/365) for molecule:  C3O3H6;v29=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (46/365) for molecule:  C3O3H6;v30=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (47/365) for molecule:  C3O3H6;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (48/365) for molecule:  C4S;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (49/365) for molecule:  C5N-;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (50/365) for molecule:  C5S-34;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (51/365) for molecule:  C6D;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (52/365) for molecule:  C7H;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (53/365) for molecule:  C9S;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (54/365) for molecule:  CC-13-C3H;v=0;hyp2 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (55/365) for molecule:  CCCCD;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (56/365) for molecule:  CCCCH;v7=2;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (57/365) for molecule:  CCCO;v5=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (58/365) for molecule:  CH2(OD)CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (59/365) for molecule:  CH2(OH)C-13-HO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (60/365) for molecule:  CH2(OH)CDO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (61/365) for molecule:  CH2C-13-HCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (62/365) for molecule:  CH2CDCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (63/365) for molecule:  CH2CHC-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (64/365) for molecule:  CH2DCCH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (65/365) for molecule:  CH2DCl-37;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (66/365) for molecule:  CH2DOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (67/365) for molecule:  CH2DipCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (68/365) for molecule:  CH2F2;v4=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (69/365) for molecule:  CH2F2;v4=1;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (70/365) for molecule:  CH2F2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (71/365) for molecule:  CH2F2;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (72/365) for molecule:  CH2OHCOOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (73/365) for molecule:  CH3C-13-H2C-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (74/365) for molecule:  CH3C-13-H2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (75/365) for molecule:  CH3C8H;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (76/365) for molecule:  CH3CDO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (77/365) for molecule:  CH3CDO;v=0;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (78/365) for molecule:  CH3CH(NH2)CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (79/365) for molecule:  CH3CHDCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (80/365) for molecule:  CH3CHNH2COOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (81/365) for molecule:  CH3CHNH2COOH;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (82/365) for molecule:  CH3CHO;v15=1-0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (83/365) for molecule:  CH3CHO;v15=1-0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (84/365) for molecule:  CH3CHO;v15=1-0;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (85/365) for molecule:  CH3CHO;v15=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (86/365) for molecule:  CH3CHO;v15=1;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (87/365) for molecule:  CH3CHO;v15=1;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (88/365) for molecule:  CH3CHO;v15=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (89/365) for molecule:  CH3CHO;v15=2;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (90/365) for molecule:  CH3CHO;v15=2;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (91/365) for molecule:  CH3CHO;v15=2;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (92/365) for molecule:  CH3CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (93/365) for molecule:  CH3CHO;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (94/365) for molecule:  CH3CHO;v=0;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (95/365) for molecule:  CH3CHO;v=0;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (96/365) for molecule:  CH3CHOHCHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (97/365) for molecule:  CH3COCH3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (98/365) for molecule:  CH3COOH;v18=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (99/365) for molecule:  CH3COOH;v18=2-1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (100/365) for molecule:  CH3COOH;v18=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (101/365) for molecule:  CH3COOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (102/365) for molecule:  CH3NH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (103/365) for molecule:  CH3O-18-H;v12=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (104/365) for molecule:  CH3O-18-H;v12=1;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (105/365) for molecule:  CH3O-18-H;v12=1;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (106/365) for molecule:  CH3O-18-H;v12=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (107/365) for molecule:  CH3O-18-H;v12=2;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (108/365) for molecule:  CH3O-18-H;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (109/365) for molecule:  CH3O-18-H;v=0;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (110/365) for molecule:  CH3O-18-H;v=0;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (111/365) for molecule:  CH3OC-13-HO;v18=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (112/365) for molecule:  CH3OC-13-HO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (113/365) for molecule:  CH3OCH2CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (114/365) for molecule:  CH3OCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (115/365) for molecule:  CH3OCH3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (116/365) for molecule:  CH3OCHO;v18=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (117/365) for molecule:  CH3OCHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (118/365) for molecule:  CH3OH;v12=2-1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (119/365) for molecule:  CH3OH;v12=2-1;E ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (120/365) for molecule:  CH3OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (121/365) for molecule:  CH3OH;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (122/365) for molecule:  CH3OH;v=0;#2 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (123/365) for molecule:  CH3OH;v=0;A ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (124/365) for molecule:  CH3OOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (125/365) for molecule:  CH3S-34-H;v12=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (126/365) for molecule:  CH3S-34-H;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (127/365) for molecule:  CH3SD;v12=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (128/365) for molecule:  CH3SD;v12=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (129/365) for molecule:  CHOCHOHCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (130/365) for molecule:  CHOCOOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (131/365) for molecule:  CS-33;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (132/365) for molecule:  CS-33;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (133/365) for molecule:  CaNC;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (134/365) for molecule:  CaNC;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (135/365) for molecule:  CaNC;v=0;#2 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (136/365) for molecule:  Cl-35-ONO2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (137/365) for molecule:  Cl-37-ONO2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (138/365) for molecule:  Cl-37-OOCl;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (139/365) for molecule:  ClClO2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (140/365) for molecule:  ClOOCl;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (141/365) for molecule:  Cr-52-Cl-37;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (142/365) for molecule:  Cr-52-Cl-37;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (143/365) for molecule:  D2CS;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (144/365) for molecule:  D2CS;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (145/365) for molecule:  D2NCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (146/365) for molecule:  DCCCCCCCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (147/365) for molecule:  DCCCHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (148/365) for molecule:  DCOOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (149/365) for molecule:  DNO3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (150/365) for molecule:  E-CH2(CH)3CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (151/365) for molecule:  G'Gg'gg'-CH2(OH)CH(OH)CH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (152/365) for molecule:  GA-n-C4H9CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (153/365) for molecule:  GGag'g'-CH2(OH)CH(OH)CH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (154/365) for molecule:  Ga-n-C3H7OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (155/365) for molecule:  H2C(CCH)2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (156/365) for molecule:  H2C(CN)2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (157/365) for molecule:  H2C4S;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (158/365) for molecule:  H2CCCHCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (159/365) for molecule:  H2CCHC-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (160/365) for molecule:  H2CCNH;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (161/365) for molecule:  H2CCNH;v=0;hyp1;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (162/365) for molecule:  H2CCNH;v=0;hyp1;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (163/365) for molecule:  H2CNCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (164/365) for molecule:  H2CO-18;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (165/365) for molecule:  H2CO-18;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (166/365) for molecule:  H2CP;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (167/365) for molecule:  H2CP;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (168/365) for molecule:  H2N-15-CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (169/365) for molecule:  H2N-15-CN;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (170/365) for molecule:  H2N-15-CN;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (171/365) for molecule:  H2NC(O)NH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (172/365) for molecule:  H2NCH2CN;v11=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (173/365) for molecule:  H2NCH2CN;v18=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (174/365) for molecule:  H2NCH2COOH,II;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (175/365) for molecule:  H2NCH2COOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (176/365) for molecule:  H2NCO2CH3;v24=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (177/365) for molecule:  H2NCO2CH3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (178/365) for molecule:  H2O2;v4=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (179/365) for molecule:  H2O2;v4=1;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (180/365) for molecule:  H2SO4;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (181/365) for molecule:  H2SO4;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (182/365) for molecule:  H3CCHCH2O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (183/365) for molecule:  HC(O-18)NH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (184/365) for molecule:  HC-13-CCCCCCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (185/365) for molecule:  HC-13-CCN;v6=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (186/365) for molecule:  HC-13-CCN;v7=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (187/365) for molecule:  HC-13-OOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (188/365) for molecule:  HC5O;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (189/365) for molecule:  HC5S;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (190/365) for molecule:  HC7C-13-CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (191/365) for molecule:  HC7O;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (192/365) for molecule:  HC8C-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (193/365) for molecule:  HCCCCCCCN-15;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (194/365) for molecule:  HCCCCCCCN;v15=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (195/365) for molecule:  HCCCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (196/365) for molecule:  HCCCH2OD;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (197/365) for molecule:  HCCCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (198/365) for molecule:  HCCCN-15;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (199/365) for molecule:  HCOCH2OH;v12=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (200/365) for molecule:  HCOCH2OH;v17=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (201/365) for molecule:  HCOCH2OH;v18=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (202/365) for molecule:  HCOCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (203/365) for molecule:  HCOOD;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (204/365) for molecule:  HCl-37-CO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (205/365) for molecule:  HDNCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (206/365) for molecule:  HN-15-O3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (207/365) for molecule:  HNO3;v5=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (208/365) for molecule:  HNO3;v6=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (209/365) for molecule:  HNO3;v8=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (210/365) for molecule:  HNO3;v9=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (211/365) for molecule:  HNO3;v9=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (212/365) for molecule:  HNO3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (213/365) for molecule:  HO-18-NO2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (214/365) for molecule:  HO3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (215/365) for molecule:  HOCH2C(O)NH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (216/365) for molecule:  HOCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (217/365) for molecule:  HOCHCHCHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (218/365) for molecule:  HOCHCHCHO;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (219/365) for molecule:  HOCHCHCHO;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (220/365) for molecule:  HONO-18-O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (221/365) for molecule:  HONO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (222/365) for molecule:  HONOO-18;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (223/365) for molecule:  HOONO2;v12=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (224/365) for molecule:  HOONO2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (225/365) for molecule:  HOONO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (226/365) for molecule:  HSCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (227/365) for molecule:  K-39-Cl-37;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (228/365) for molecule:  K-39-Cl-37;v=12; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (229/365) for molecule:  K-41-Cl-35;v=13; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (230/365) for molecule:  K-41-OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (231/365) for molecule:  KCl-37;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (232/365) for molecule:  KCl-37;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (233/365) for molecule:  MnO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (234/365) for molecule:  N-15-NO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (235/365) for molecule:  NC-13-CNH+;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (236/365) for molecule:  NCC(O)NH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (237/365) for molecule:  NCCNO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (238/365) for molecule:  NCHCCO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (239/365) for molecule:  NCHCCO;v=0;hyp1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (240/365) for molecule:  NH2CH2CH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (241/365) for molecule:  NH2CH2CH2OH;v25=1,v27=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (242/365) for molecule:  NH2CH2CH2OH;v25=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (243/365) for molecule:  NH2CH2CH2OH;v26=1,v27=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (244/365) for molecule:  NH2CH2CH2OH;v26=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (245/365) for molecule:  NH2CH2CH2OH;v27=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (246/365) for molecule:  NH2CH2CH2OH;v27=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (247/365) for molecule:  NH2CH2CH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (248/365) for molecule:  NH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (249/365) for molecule:  NH2CN;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (250/365) for molecule:  NH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (251/365) for molecule:  NaO;v=3; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (252/365) for molecule:  O3;v2=1,v3=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (253/365) for molecule:  O3;v2=2; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (254/365) for molecule:  OBr-81-O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (255/365) for molecule:  OC(CN)2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (256/365) for molecule:  OCl-35-O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (257/365) for molecule:  OCl-37-O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (258/365) for molecule:  PO2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (259/365) for molecule:  PS;v=1-0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (260/365) for molecule:  S-34-O2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (261/365) for molecule:  S-34-O2;v=0;#1 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (262/365) for molecule:  S-34-O2;v=0;#2 ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (263/365) for molecule:  S2O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (264/365) for molecule:  S3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (265/365) for molecule:  S4;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# ...
# Prepare single molecule fit (278/365) for molecule:  Ti-46-O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (279/365) for molecule:  Ti-50-O2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (280/365) for molecule:  Z-CH2(CH)3CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (281/365) for molecule:  Z-HNCHCN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (282/365) for molecule:  a'GG'g-CH2OHCH2CH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (283/365) for molecule:  a-(CH3)2CHCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (284/365) for molecule:  a-C2H5SH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (285/365) for molecule:  a-CH3CHDOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (286/365) for molecule:  a-H2C=CHOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (287/365) for molecule:  a-a-CH2DCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (288/365) for molecule:  a-i-C3H7OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (289/365) for molecule:  aGg'-(CH2OH)2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (290/365) for molecule:  aGg'-CH3CHOHCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (291/365) for molecule:  aa-(C2H5)2O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (292/365) for molecule:  ag-(C2H5)2O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (293/365) for molecule:  anti-CH2CCHCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (294/365) for molecule:  bc-C4H4C2H2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (295/365) for molecule:  bc-C6H6CH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (296/365) for molecule:  c-C10H8;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (297/365) for molecule:  c-C12H8;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (298/365) for molecule:  c-C13H10;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (299/365) for molecule:  c-C2H3(O)CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (300/365) for molecule:  c-C2H4NH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (301/365) for molecule:  c-C2H4S;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (302/365) for molecule:  c-C2H4S;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (303/365) for molecule:  c-C3H5CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (304/365) for molecule:  c-C3H6O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (305/365) for molecule:  c-C3H6O;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (306/365) for molecule:  c-C3H6O;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (307/365) for molecule:  c-C3H;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (308/365) for molecule:  c-C3HD;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (309/365) for molecule:  c-C4H2(CH2)2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (310/365) for molecule:  c-C4H4O2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (311/365) for molecule:  c-C4H4O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (312/365) for molecule:  c-C4H4O;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (313/365) for molecule:  c-C4H4O;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (314/365) for molecule:  c-C5H4C2H4;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (315/365) for molecule:  c-C5H4CCH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (316/365) for molecule:  c-C5H4CCH2;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (317/365) for molecule:  c-C5H4CH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (318/365) for molecule:  c-C5H4CH2;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (319/365) for molecule:  c-C5H4O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (320/365) for molecule:  c-C5H4O;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (321/365) for molecule:  c-C5H5N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (322/365) for molecule:  c-C5H5N;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (323/365) for molecule:  c-C5H5N;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (324/365) for molecule:  c-C5H6-D1;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (325/365) for molecule:  c-C5H6-D2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (326/365) for molecule:  c-C5H6;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (327/365) for molecule:  c-C5H6;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (328/365) for molecule:  c-C5H6;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (329/365) for molecule:  c-C6H4;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (330/365) for molecule:  c-C6H4;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (331/365) for molecule:  c-C6H4;v=0;para ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (332/365) for molecule:  c-C6H5CCH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (333/365) for molecule:  c-C6H5CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (334/365) for molecule:  c-C6H5CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (335/365) for molecule:  c-C6H5OCH3;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (336/365) for molecule:  c-C6H5OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (337/365) for molecule:  c-C6H6CH2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (338/365) for molecule:  c-C9H8;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (339/365) for molecule:  c-D2C3O;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (340/365) for molecule:  c-H2C2Si;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (341/365) for molecule:  c-H2C2Si;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (342/365) for molecule:  c-H2C3O-18;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (343/365) for molecule:  c-HC(O)SH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (344/365) for molecule:  c-HCOOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (345/365) for molecule:  g'Ga-CH3CHOHCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (346/365) for molecule:  g'Gg-CH3CHOHCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (347/365) for molecule:  g-(CH3)2CHCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (348/365) for molecule:  g-C2H5CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (349/365) for molecule:  g-C2H5S-34-H;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (350/365) for molecule:  g-C2H5SH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (351/365) for molecule:  g-i-C3H7OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (352/365) for molecule:  gG'g'-CH3CHOHCH2OH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (353/365) for molecule:  gGg'-(CH2OH)2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (354/365) for molecule:  i-C3H7C-13-N;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (355/365) for molecule:  i-C3H7CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (356/365) for molecule:  l-C3H2;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (357/365) for molecule:  l-C3H2;v=0;ortho ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (358/365) for molecule:  s-C2H5CHO;v23=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (359/365) for molecule:  s-C2H5CHO;v24=1; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (360/365) for molecule:  s-C2H5CHO;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (361/365) for molecule:  s-cis-H2C=CHCOOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (362/365) for molecule:  s-trans-H2C=CHCOOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (363/365) for molecule:  syn-CH2CCHCH2CN;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (364/365) for molecule:  t-HC(O)SH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
# Prepare single molecule fit (365/365) for molecule:  t-HC-13-OOH;v=0; ..                                                                          Adjust MAGIX XML file .. done!
#
# Perform single molecule fit for (CH3)2C-13-HCN;v=0;..
# Start single molecule fit for "(CH3)2C-13-HCN;v=0;" on node: localhost
#
# Perform single molecule fit for (Z)-HC2CHCHCN;v=0;..
# Start single molecule fit for "(Z)-HC2CHCHCN;v=0;" on node: localhost

# %% [markdown]
# # List Database

# %%
from xclass import task_ListDatabase

# call ListDatabase function

FreqMin = 97041.16

FreqMax = 98912.35

ElowMin = 100.0

ElowMax = 2000.0

SelectMolecule = []

OutputDevice = " "

Contents = task_ListDatabase.ListDatabase(FreqMin, FreqMax, ElowMin, \
                                              ElowMax, SelectMolecule, \
                                              OutputDevice)
# Out:
#
#
# Analyze selected molecules ..
#
#
# Reading data from sqlite3 database .. done!
#
#
# Contents of the database between 97041.16 MHz and 98912.35 MHz:
#
# Name:                    quantum number upper state:          quantum number lower state:          Frequency [MHz]:  Error Frequency [MHz]:  Einstein A coefficient:    Energy_low [K]:       upper state degeneracy:
# HOCH2CN;v=0;                X;vibInv=a;J=73;Ka=3;Kc=70;          X;vibInv=s;J=73;Ka=4;Kc=70;              97063.25060              8.8100e-02                  8.786e-06            1212.231                   1.5e+02
# g-i-C3H7OH;v=0;             X;vibInv=s;J=27;Ka=9;Kc=19;          X;vibInv=a;J=27;Ka=7;Kc=20;              97063.27320              4.2000e-03                  1.434e-06             236.015                   5.5e+01
# g-i-C3H7OH;v=0;             X;vibInv=s;J=27;Ka=8;Kc=19;          X;vibInv=a;J=27;Ka=8;Kc=20;              97063.27320              4.2000e-03                  1.434e-06             236.015                   5.5e+01
# CH3CHOHCHO;v=0;             X;J=24;Ka=4;Kc=21;                   X;J=24;Ka=3;Kc=22;                       97063.90050              5.0000e-02                  6.791e-06             103.638                   4.9e+01
# C-13-H3(CH3)CHCN;v=0;       X;J=28;Ka=5;Kc=23;                   X;J=28;Ka=5;Kc=24;                       97063.92890              2.3130e-01                  5.481e-06             136.305                   5.7e+01
# CH3CHOHCHO;v=0;             X;J=24;Ka=4;Kc=21;                   X;J=24;Ka=2;Kc=22;                       97064.21410              2.9000e-03                  2.033e-07             103.638                   4.9e+01
# NH2CH2CH2CN;v=0;            X;J=42;Ka=11;Kc=31;                  X;J=41;Ka=12;Kc=30;                      97064.57940              8.8000e-03                  2.586e-06             307.711                   8.5e+01
# CH3COOH;v18=2;              X;v18=2;J=8;Ka=2;Kc=7;rotSym=E;      X;v18=2;J=7;Ka=2;Kc=6;rotSym=E;          97064.69170              3.2000e-03                  2.705e-06             214.707                   1.7e+01
# HN-15-O3;v=0;               X;J=38;Ka=28;Kc=10;                  X;J=38;Ka=28;Kc=11;                      97064.85100              1.0000e-01                  6.336e-06             850.588                   7.7e+01
# HN-15-O3;v=0;#1             X;J=38;Ka=28;Kc=10;                  X;J=38;Ka=28;Kc=11;                      97064.85100              1.0000e-01                  6.336e-06             850.588                   7.7e+01
# CH3O-18-H;v12=1;E           X;v12=1;J=16;Ka=2;Kc=15;rovibSy...   X;v12=1;J=15;Ka=5;Kc=10;rovibSy...       97065.40200              6.4000e-01                  2.025e-09             687.313                   1.3e+02
# CH3O-18-H;v12=1;            X;v12=1;J=16;Ka=2;Kc=15;rovibSy...   X;v12=1;J=15;Ka=5;Kc=10;rovibSy...       97065.40200              6.4000e-01                  2.025e-09             695.149                   1.3e+02
# c-H2C2Si;v=0;ortho          X;J=21;Ka=5;Kc=16;                   X;J=21;Ka=5;Kc=17;                       97065.66500              9.3700e-02                  3.702e-07             258.861                   1.3e+02
# c-H2C2Si;v=0;               X;J=21;Ka=5;Kc=16;                   X;J=21;Ka=5;Kc=17;                       97065.66500              9.3700e-02                  3.702e-07             260.889                   1.3e+02
# CH3CHNH2COOH;v=0;#1         X;J=58;Ka=25;Kc=33;                  X;J=58;Ka=24;Kc=34;                      97065.93320              1.1609e+00                  5.348e-06             517.325                   3.5e+02
# NH2CH2CH2OH;v26=1,v27=1;    X;v25=0;v26=1;v27=1;J=35;Ka=5;K...   X;v25=0;v26=1;v27=1;J=34;Ka=6;K...       97066.09700              1.3497e+00                  6.415e-08             696.569                   7.1e+01
# NH2CH2CH2OH;v26=1,v27=1;#   X;v25=0;v26=1;v27=1;J=35;Ka=5;K...   X;v25=0;v26=1;v27=1;J=34;Ka=6;K...       97066.09700              1.3497e+00                  6.415e-08             696.569                   7.1e+01
# a-(CH3)2CHCH2CN;v=0;        X;J=47;Ka=8;Kc=40;                   X;J=46;Ka=9;Kc=37;                       97066.31140              8.6000e-03                  8.689e-07             223.998                   1.9e+02
# g'Ga-CH3CHOHCH2OH;v=0;      X;J=56;Ka=21;Kc=35;                  X;J=56;Ka=20;Kc=37;                      97066.52880              1.0300e-02                  4.944e-07             641.711                   1.1e+02
# ...
# HCl-37-CO;v=0;#1            X;J=57;Ka=3;Kc=55;F_Cl=55.5;         X;J=56;Ka=4;Kc=52;F_Cl=55.5;             98397.34110              1.8020e-01                  9.484e-10             943.068                   1.1e+02
# NH2CH2CH2OH;v25=1;          X;v25=1;v26=0;v27=0;J=28;Ka=0;K...   X;v25=1;v26=0;v27=0;J=27;Ka=1;K...       98397.65190              8.8900e-02                  2.654e-08             615.849                   5.7e+01
# NH2CH2CH2OH;v25=1;#1        X;v25=1;v26=0;v27=0;J=28;Ka=0;K...   X;v25=1;v26=0;v27=0;J=27;Ka=1;K...       98397.65190              8.8900e-02                  2.654e-08             615.849                   5.7e+01
# HCCCCCCCN;v15=2;            X;v15=2;l15=0;J=87;kronigParity=e;   X;v15=2;l15=0;J=86;kronigParity=e;       98397.67540              3.8000e-03                  1.281e-04             381.540                   1.8e+02
# c-C10H8;v=0;                X;J=52;Ka=4;Kc=48;                   X;J=51;Ka=4;Kc=47;                       98397.81810              6.5000e-03                  3.382e-06             128.976                   1.0e+02
# c-C10H8;v=0;                X;J=52;Ka=5;Kc=48;                   X;J=51;Ka=5;Kc=47;                       98397.81810              6.5000e-03                  3.382e-06             128.976                   1.0e+02
# H2O+;v=0;hyp2;para          X;S=0.5;J=5.5;N=6;Ka=3;Kc=4;I_H...   X;S=0.5;J=4.5;N=5;Ka=4;Kc=1;I_H...       98397.91170              1.6892e+01                  1.334e-06             840.556                   1.2e+01
# H2O+;v=0;hyp2               X;S=0.5;J=5.5;N=6;Ka=3;Kc=4;I_H...   X;S=0.5;J=4.5;N=5;Ka=4;Kc=1;I_H...       98397.91170              1.6892e+01                  1.334e-06             870.566                   1.2e+01
# CH3S-34-H;v=0;              X;v12=0;J=13;Ka=3;Kc=11;rotSym=...   X;v12=0;J=14;Ka=2;Kc=13;rotSym=...       98398.03960              3.1000e-03                  9.865e-09             142.890                   2.7e+01
# c-C5H6;v=0;para             X;J=21;Ka=18;Kc=3;                   X;J=21;Ka=15;Kc=6;                       98398.45680              1.4330e-01                  3.032e-09             176.871                   3.0e+02
# c-C5H6;v=0;                 X;J=21;Ka=18;Kc=3;                   X;J=21;Ka=15;Kc=6;                       98398.45680              1.4330e-01                  3.032e-09             177.471                   3.0e+02
# HCOCH2OH;v17=1;             X;v12=0;v17=1;v18=0;J=3;Ka=3;Kc=0;   X;v12=0;v17=1;v18=0;J=2;Ka=2;Kc=1;       98398.91860              9.1000e-03                  2.904e-05             455.709                   7.0e+00
# a'GG'g-CH2OHCH2CH2OH;v=0;   X;vibInv=s;J=63;Ka=15;Kc=49;         X;vibInv=a;J=62;Ka=17;Kc=46;             98399.44470              1.0210e-01                  1.527e-07             711.092                   1.3e+02
# C2H5CN;v12=1;               X;v12=1;J=11;Ka=9;Kc=2;              X;v12=1;J=10;Ka=9;Kc=1;                  98399.54800              5.0000e-02                  2.553e-05             884.093                   2.3e+01
# C2H5CN;v12=1;               X;v12=1;J=11;Ka=9;Kc=3;              X;v12=1;J=10;Ka=9;Kc=2;                  98399.54800              5.0000e-02                  2.553e-05             884.093                   2.3e+01
# CH3CHOHCHO;v=0;             X;J=30;Ka=10;Kc=21;                  X;J=30;Ka=8;Kc=22;                       98399.59940              3.7000e-03                  1.756e-07             186.656                   6.1e+01
# HOONO2;v12=1;               X;v12=1;vibInv=a;J=35;Ka=5;Kc=31;    X;v12=1;vibInv=s;J=34;Ka=6;Kc=29;        98399.82200              1.2828e+00                  7.075e-07             454.824                   7.1e+01
# HOONO2;v12=1;#1             X;v12=1;vibInv=a;J=35;Ka=5;Kc=31;    X;v12=1;vibInv=s;J=34;Ka=6;Kc=29;        98399.82200              1.2828e+00                  7.075e-07             454.824                   7.1e+01
# H2CCCHCN;v=0;               X;J=77;Ka=4;Kc=74;                   X;J=76;Ka=5;Kc=71;                       98399.98720              1.9066e+01                  6.878e-07             757.254                   4.6e+02
# S4;v=0;                     X;vibSym=-;J=48;Ka=20;Kc=28;         X;vibSym=+;J=48;Ka=19;Kc=29;             98400.37640              7.5300e-02                  4.073e-06             263.821                   9.7e+01
# S4;v=0;#1                   X;vibSym=-;J=48;Ka=20;Kc=28;         X;vibSym=+;J=48;Ka=19;Kc=29;             98400.37640              7.5300e-02                  4.073e-06             263.821                   9.7e+01
# c-C4H2(CH2)2;v=0;ortho      X;J=26;Ka=25;Kc=2;                   X;J=26;Ka=24;Kc=3;                       98400.69200              2.9700e-02                  2.429e-07             175.068                   4.8e+02
# c-C4H2(CH2)2;v=0;para       X;J=26;Ka=25;Kc=1;                   X;J=26;Ka=24;Kc=2;                       98400.69200              2.9700e-02                  2.429e-07             175.388                   3.7e+02
# c-C4H2(CH2)2;v=0;           X;J=26;Ka=25;Kc=1;                   X;J=26;Ka=24;Kc=2;                       98400.69200              2.9700e-02                  2.429e-07             175.388                   3.7e+02
# c-C4H2(CH2)2;v=0;           X;J=26;Ka=25;Kc=2;                   X;J=26;Ka=24;Kc=3;                       98400.69200              2.9700e-02                  2.429e-07             175.388                   4.8e+02
# CHOCHOHCH2OH;v=0;           X;J=64;Ka=15;Kc=49;                  X;J=64;Ka=14;Kc=51;                      98400.83290              6.6385e+00                  2.931e-06             551.200                   1.3e+02
# HCOCH2OH;v=0;               X;v12=0;v17=0;v18=0;J=25;Ka=5;K...   X;v12=0;v17=0;v18=0;J=25;Ka=5;K...       98401.11190              1.3600e-02                  3.427e-09             197.005                   5.1e+01
# HCl-37-CO;v=0;#1            X;J=68;Ka=4;Kc=64;F_Cl=69.5;         X;J=68;Ka=4;Kc=65;F_Cl=69.5;             98403.08370              5.1540e-01                  2.596e-09            1357.640                   1.4e+02
# HCl-37-CO;v=0;              X;J=68;Ka=4;Kc=64;F_Cl=66.5;         X;J=68;Ka=4;Kc=65;F_Cl=66.5;             98403.09550              5.1540e-01                  2.596e-09            1357.640                   1.3e+02
# HCl-37-CO;v=0;#1            X;J=68;Ka=4;Kc=64;F_Cl=66.5;         X;J=68;Ka=4;Kc=65;F_Cl=66.5;             98403.09550              5.1540e-01                  2.596e-09            1357.640                   1.3e+02
# c-CCC-13-H2;v=0;            X;J=8;Ka=5;Kc=3;                     X;J=8;Ka=5;Kc=4;                         98403.26650              7.0000e-03                  4.088e-07             101.029                   3.4e+01
# c-C6H5CHO;v=0;              X;J=94;Ka=17;Kc=77;                  X;J=94;Ka=17;Kc=78;                      98403.43960              9.2100e-02                  1.247e-06             661.411                   1.9e+02
# C3H6O2;v=0;                 X;J=88;Ka=13;Kc=75;rovibSym=E;       X;J=89;Ka=12;Kc=78;rovibSym=E;           98403.47780              2.1186e+02                  7.884e-08            1330.381                   1.8e+02
# C3H6O2;v=0;#1               X;J=88;Ka=13;Kc=75;rovibSym=E;       X;J=89;Ka=12;Kc=78;rovibSym=E;           98403.47780              2.1186e+02                  7.884e-08            1330.381                   1.8e+02
# c-C6H4;v=0;ortho            X;J=72;Ka=45;Kc=27;                  X;J=72;Ka=44;Kc=28;                      98404.12910              7.9190e-01                  7.854e-06            1438.515                   7.2e+02
# c-C6H4;v=0;                 X;J=72;Ka=45;Kc=27;                  X;J=72;Ka=44;Kc=28;                      98404.12910              7.9190e-01                  7.854e-06            1438.515                   7.2e+02
# C3O3H6;v=0;                 X;v28=0;v29=0;v30=0;J=95;Ka=30;...   X;v28=0;v29=0;v30=0;J=96;Ka=29;...       98404.76000              4.7100e-02                  2.075e-06            1166.399                   1.9e+02
# C3O3H6;v=0;                 X;v28=0;v29=0;v30=0;J=95;Ka=30;...   X;v28=0;v29=0;v30=0;J=96;Ka=29;...       98404.76000              4.7100e-02                  2.075e-06            1166.399                   1.9e+02
# C3O3H6;v=0;#1               X;v28=0;v29=0;v30=0;J=95;Ka=30;...   X;v28=0;v29=0;v30=0;J=96;Ka=29;...       98404.76000              4.7100e-02                  2.075e-06            1166.399                   1.9e+02
# C3O3H6;v=0;#1               X;v28=0;v29=0;v30=0;J=95;Ka=30;...   X;v28=0;v29=0;v30=0;J=96;Ka=29;...       98404.76000              4.7100e-02                  2.075e-06            1166.399                   1.9e+02
# C3H8;v=0;                   X;v14=0;v27=0;J=30;Ka=7;Kc=24;r...   X;v14=0;v27=0;J=31;Ka=4;Kc=27;r...       98404.78100              6.7800e-02                  9.484e-11             401.299                   2.4e+02
# C3H8;v=0;#1                 X;v14=0;v27=0;J=30;Ka=7;Kc=24;r...   X;v14=0;v27=0;J=31;Ka=4;Kc=27;r...       98404.78100              6.7800e-02                  9.484e-11             401.299                   2.4e+02
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
