# %%
import astropy.io.fits as fits
import matplotlib.pyplot as plt    
from matplotlib.patches import Rectangle
from astropy.wcs import WCS                 
from astropy import units as u  
import pylab
import numpy as np
from spectral_cube import SpectralCube     
import pyspeckit
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %% [markdown]
# # Finds center of cloud c

# %%
path="B.Dust_Ridge_sci.spw25_27_29_31.cont.I.tt0.pbcor.fits"
header=fits.getheader(path)
w1=WCS(header)
w1 = w1.dropaxis(3)
w1 = w1.dropaxis(2)

#finds the pixel positions for the RA and dec
#find RA DEC of x,y,z
core_coords=w1.pixel_to_world(175,166)
print(core_coords)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (266.58818356, -28.59536026)>

# %% [markdown]
# # Plots Spectrum

# %%
#reads in file
path="B.Dust_Ridge_12C17O.cube.I.pbcor.fits"
#makes figure
fig1=pylab.figure(1,figsize=(15,2),dpi=250)



#find the corresponding pixel positions for those coords in new image
header=fits.getheader(path)
w2=WCS(header)
image_coords=core_coords.to_pixel(w2,0,mode="wcs")
print(image_coords)

#plots spectrum
sc=SpectralCube.read(path)
sc.allow_huge_operations=True 
sc_Ghz=sc.with_spectral_unit(u.GHz)
sc_Ghz=sc_Ghz.to(u.K)
freq,Dec,Ra = sc_Ghz.world[:,0,0] 
subcube=sc_Ghz.hdu.data[:,int(image_coords[0])-5:int(image_coords[0])+5,int(image_coords[1])-5:int(image_coords[1])+5]
spectrum = np.average(subcube,axis=(1,2)) 
ax1=pylab.subplot()
ax1.plot(freq,spectrum,lw=1,drawstyle='steps-mid',color="SteelBlue")
pylab.xlabel("Frequency (GHz)", fontsize=10)
    
pylab.ylabel('Brightness Temp. (K)',fontsize=10)


plt.rcParams['text.usetex'] = True

Noise_upper=1600
Noise_lower=1560
width=freq[Noise_upper]-freq[Noise_lower]
print(f"Noise lower: {freq[Noise_lower]}")
print(f"Noise upper: {freq[Noise_upper]}")
print(f"Width: {width}")
#lower line
pylab.vlines(freq[Noise_lower].value,-1,4,colors="black")
#upper line
pylab.vlines(freq[Noise_upper].value,-1,4,colors="black")
#calculate 3 sigma
sigma=np.std(spectrum[Noise_lower:Noise_upper])
three_sigma=3*sigma
#three_sigma_Jy=three_sigma.to(u.jansky)
print(f"sigma: {sigma} K")
print(f"3 sigma: {three_sigma} K")
#print(f"3 sigma: {three_sigma_Jy} Jy")
pylab.hlines(three_sigma,freq[0].value,freq[1916].value,colors="red",label =r'$3 \sigma$',ls="--" )


#12C17O
pylab.vlines(112.344,-1,4,colors="green",label=r"${}^{12}C^{17}O$")

pylab.xlim(112.24234204000003,112.47624743612477)
pylab.ylim(-1,4)
ax1.fill_between(freq.value,three_sigma, -1, alpha = 0.2, color= 'red' )
plt.legend(loc="upper left",fontsize=15)
#plt.title()
plt.savefig("12C17O.pdf")
# Out:
# (array(175.), array(166.))
# Noise lower: 112.43278693454835 GHz
# Noise upper: 112.43767013697267 GHz
# Width: 0.00488320242432394 GHz
# sigma: 0.0739014447368852 K
# 3 sigma: 0.2217043342106556 K

# %% [markdown]
# # Sigma Noise

# %%
sigma_pop=np.std(spectrum[0:350])
sigma_sample=np.std(spectrum[0:350], ddof=1)
print(sigma_sample)
print(sigma_pop)
print(freq[0],freq[350])
# Out:
# 0.0960488688467246
# 0.09591155802763028
# 112.24234204000003 GHz 112.28507006121279 GHz

# %% [markdown]
# # CO line ID

# %%
#zooms in on major intensity spike (assumed to be 12CO)
zoom = np.where((freq.value>112.3)*(freq.value<112.4))


#zooms in on the spectrum we found in the last code block
zoom_13C160=spectrum[zoom]
print(len(zoom_13C160))

#zooms in on the frequency's in this zoomed in region
zoom_freq = freq[zoom]


error = np.zeros(np.size(zoom))
wheremeas = np.where((zoom_freq.value>110.16)*(zoom_freq.value<110.17))
meas = np.std(spectrum[0:550])
print(meas)
error = error + meas

#print((zoom_13C160))
sp = pyspeckit.Spectrum(data=zoom_13C160,xarr=zoom_freq,error=error,unit="K")
fig1 = pylab.figure(1,figsize=(5,5),dpi=250)
sp.plotter(axis=pylab.subplot(1,1,1), title="Acetone")
sp.specfit(fittype='gaussian')
sp.plotter.savefig('COline_13C16O.png')
#print(sp.specfit.parinfo)
# Out:
# 819
# 0.11596006737818514

# %%
#zooms in on major intensity spike (assumed to be 12CO)
zoom = np.where((freq.value>112.32)*(freq.value<112.35))


#zooms in on the spectrum we found in the last code block
zoom_13C160=spectrum[zoom]
print(len(zoom_13C160))

#zooms in on the frequency's in this zoomed in region
zoom_freq = freq[zoom]


error = np.zeros(np.size(zoom))
wheremeas = np.where((zoom_freq.value>110.16)*(zoom_freq.value<110.17))
meas = np.std(spectrum[0:550])
print(meas)
error = error + meas

#print((zoom_13C160))
sp = pyspeckit.Spectrum(data=zoom_13C160,xarr=zoom_freq,error=error,unit="K")
fig1 = pylab.figure(1,figsize=(5,5),dpi=250)
sp.plotter(axis=pylab.subplot(1,1,1), title="12C17O")
sp.specfit(fittype='gaussian')
sp.plotter.savefig('12C17Ogaussianprofileplot.pdf')
#print(sp.specfit.parinfo)
# Out:
# 245
# 0.11596006737818514

# %% [markdown]
# # Line ID

# %%
import pyspeckit
#Creates regions zoomed around feature
zoom = np.where((freq.value>112.3)*(freq.value<112.4))
zoom_spectrum=spectrum[zoom]
zoom_freq = freq[zoom]

#Calculates the error 
error = np.zeros(np.size(zoom))
meas = sigma #uses sigma calc from previous block
error = error + meas

#plots the gaussian fit
sp = pyspeckit.Spectrum(data=zoom_spectrum,xarr=zoom_freq,error=error,unit='K')
fig1 = pylab.figure(1,figsize=(5,5),dpi=250)
sp.plotter(axis=pylab.subplot(1,1,1),title=r"${}^{12}C^{17}O$")
sp.specfit(fittype='gaussian')
sp.plotter.savefig('12C17O.brightest.pdf')
sp.plotter.savefig('12C17O.brightest.png')
print(sp.specfit.parinfo)
# Out:
# Param #0   AMPLITUDE0 =     0.694283 +/-       0.0191732
# Param #1       SHIFT0 =       112.36 +/-     4.89444e-05
# Param #2       WIDTH0 =   0.00153491 +/-     4.89444e-05   Range:   [0,inf)
